# %% [markdown]
# ## Part 1

# %% [markdown]
# <h4>EDA</h4>

# %%
import pandas as pd
import numpy as np

# %%
path = r"C:\Users\ct_vi\Desktop\Machine_Learning_Act\Group_Ass\Ev Charging Pattern Cleaned Dataset.csv"

# %%
dataset = pd.read_csv(path)

# %%
dataset.head(5)
# Out:
#   User ID Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# 0  User_1        BMW i3              108.463007         Station_391
# 1  User_2  Hyundai Kona              100.000000         Station_428
# 2  User_3    Chevy Bolt               75.000000         Station_181
# 3  User_4  Hyundai Kona               50.000000         Station_327
# 4  User_5  Hyundai Kona               50.000000         Station_108
#
#   Charging Station Location  Charging Start Time    Charging End Time  \
# 0                   Houston  2024-01-01 00:00:00  2024-01-01 00:39:00
# 1             San Francisco  2024-01-01 01:00:00  2024-01-01 03:01:00
# 2             San Francisco  2024-01-01 02:00:00  2024-01-01 04:48:00
# 3                   Houston  2024-01-01 03:00:00  2024-01-01 06:42:00
# 4               Los Angeles  2024-01-01 04:00:00  2024-01-01 05:46:00
#
#    Energy Consumed (kWh)  Charging Duration (hours)  Charging Rate (kW)  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
print(dataset.dtypes)
# Out:
# User ID                                      object
# Vehicle Model                                object
# Battery Capacity (kWh)                      float64
# Charging Station ID                          object
# Charging Station Location                    object
# Charging Start Time                          object
# Charging End Time                            object
# Energy Consumed (kWh)                       float64
# Charging Duration (hours)                   float64
# Charging Rate (kW)                          float64
# Charging Cost (USD)                         float64
# Time of Day                                  object
# Day of Week                                  object
# State of Charge (Start %)                   float64
# State of Charge (End %)                     float64
# Distance Driven (since last charge) (km)    float64
# Temperature (°C)                            float64
# Vehicle Age (years)                         float64
# ...

# %%
dataset.corr(numeric_only=True)
# Out:
#                                           Battery Capacity (kWh)  \
# Battery Capacity (kWh)                                  1.000000
# Energy Consumed (kWh)                                   0.000316
# Charging Duration (hours)                              -0.024824
# Charging Rate (kW)                                      0.015552
# Charging Cost (USD)                                    -0.000492
# State of Charge (Start %)                              -0.072148
# State of Charge (End %)                                -0.011512
# Distance Driven (since last charge) (km)               -0.040069
# Temperature (°C)                                       -0.036411
# Vehicle Age (years)                                     0.037673
#
#                                           Energy Consumed (kWh)  \
# Battery Capacity (kWh)                                 0.000316
# Energy Consumed (kWh)                                  1.000000
# ...

# %%
sns.regplot(x='Vehicle Age (years)', y='Charging Cost (USD)', data=dataset)
plt.ylim(0,)
# Out:
# (0.0, 72.8664145039459)

# %%
from scipy.stats import pearsonr

target = 'Charging Cost (USD)'
correlation_table = {}
i = 0

for col in dataset.columns:
    if col != target:
   
        if pd.api.types.is_numeric_dtype(dataset[col]):
            corr, p_value = pearsonr(dataset[col], dataset[target])
            correlation_table[col] = {'Correlation': corr, 'P-value': p_value}
            i += 1
        else:
            print(f"Skipping non-numeric column: {col}")
            continue

result = pd.DataFrame(correlation_table).T
print(result)
print(i)
# Out:
# Skipping non-numeric column: User ID
# Skipping non-numeric column: Vehicle Model
# Skipping non-numeric column: Charging Station ID
# Skipping non-numeric column: Charging Station Location
# Skipping non-numeric column: Charging Start Time
# Skipping non-numeric column: Charging End Time
# Skipping non-numeric column: Time of Day
# Skipping non-numeric column: Day of Week
# Skipping non-numeric column: Charger Type
# Skipping non-numeric column: User Type
#                                           Correlation   P-value
# Battery Capacity (kWh)                      -0.000492  0.985744
# Energy Consumed (kWh)                       -0.007608  0.782425
# Charging Duration (hours)                    0.015902  0.563782
# Charging Rate (kW)                          -0.000831  0.975932
# State of Charge (Start %)                   -0.008653  0.753467
# State of Charge (End %)                     -0.063174  0.021712
# Distance Driven (since last charge) (km)    -0.008325  0.762504
# ...

# %%
print(correlation)
# Out:
# {'Battery Capacity (kWh)': {'Correlation': np.float64(-0.0004922606272382557), 'P-value': np.float64(0.9857443374011668)}, 'Energy Consumed (kWh)': {'Correlation': np.float64(-0.007608170724055535), 'P-value': np.float64(0.782424646893871)}, 'Charging Duration (hours)': {'Correlation': np.float64(0.01590186615349433), 'P-value': np.float64(0.5637823102699233)}, 'Charging Rate (kW)': {'Correlation': np.float64(-0.0008311661215916963), 'P-value': np.float64(0.9759321431248626)}, 'State of Charge (Start %)': {'Correlation': np.float64(-0.008652558727849403), 'P-value': np.float64(0.7534670183003378)}, 'State of Charge (End %)': {'Correlation': np.float64(-0.06317447907516155), 'P-value': np.float64(0.0217124240439055)}, 'Distance Driven (since last charge) (km)': {'Correlation': np.float64(-0.008325352395918403), 'P-value': np.float64(0.7625043678511264)}, 'Temperature (°C)': {'Correlation': np.float64(0.059864237173258866), 'P-value': np.float64(0.02964016635204032)}, 'Vehicle Age (yea
# ...

# %%
# Create subplots (one row, multiple columns)
fig, axes = plt.subplots(2, 5, figsize=(27, 15))  # 1 row, len(features) columns
i = 0

for col in dataset.columns:
    if col != target:

        if pd.api.types.is_numeric_dtype(dataset[col]):
            # Iterate over the features and plot
                sns.regplot(x=col, y=target, data=dataset, ax=axes[2])  # ax specifies the subplot location
                axes[i].set_title(f'Regplot of {col} vs Target')
        else:
            print(f"Skipping non-numeric column: {col}")
            continue




# Adjust layout
plt.tight_layout()

# Show plots
plt.show()
# Out:
# Skipping non-numeric column: User ID
# Skipping non-numeric column: Vehicle Model
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[59], line 10
#       6 if col != target:
#       8     if pd.api.types.is_numeric_dtype(dataset[col]):
#       9         # Iterate over the features and plot
# ---> 10             sns.regplot(x=col, y=target, data=dataset, ax=axes[2])  # ax specifies the subplot location
#      11             axes[i].set_title(f'Regplot of {col} vs Target')
#      12     else:
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
corr_matrix = dataset.corr(numeric_only=True)

# Set the figure size and improve appearance
plt.figure(figsize=(15, 15))

# Create a heatmap with annotations
sns.heatmap(corr_matrix, annot=True, cmap='hsv', center=0, fmt='.2f',
            annot_kws={'size': 12}, linewidths=0.5, cbar_kws={'shrink': 0.8})

# Set the title
plt.title('Correlation Matrix', fontsize=16)

# Show the plot
plt.tight_layout()
plt.show()
